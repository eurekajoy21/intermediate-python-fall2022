# %% [markdown]
# ### Step 1: Create a package named `dataframe_cleaner`

# %% [markdown]
# ### Step 2: Read the sample csv file
# * You need to read the `sample_employees.csv` file as a DataFrame and test your functions

# %% [markdown]
# ### Step 3: Create separate functions in `__init__.py`
# 1. import pandas
# 2. `drop_empty` takes pandas dataframe as an input and drops any row with empty value. Use pandas' `dropna`.
#     * Use sample `DataFrame` to test
# 3. `fill_empty` takes pandas dataframe and column name as inputs and fills the given column's empty values using mean. Use pandas' `fillna`.
#     * Use sample `DataFrame` to test
# 4. `drop_column` takes pandas dataframe and column name as inputs and drops the given column and returns the rest of the dataframe. Use pandas' `drop`.
#     * Use sample `DataFrame` to test
# 5. `fix_index` takes pandas dataframe as an input and resets its index and returns it. Use pandas' `reset_index` and drop the old index column.
#     * Use sample `DataFrame` to test
# 6. `fix_dates` takes pandas dataframe and column name as input. Changes given column's data type into datetime. Use pandas' `to_datetime` function.
#     * Use sample `DataFrame` to test

# %%
# def drop_empty(df):
#   return df.dropna()

# def fill_empty(df, col_name):
#   df[col_name] = df[col_name].fillna(df[col_name].mean())
#   return df

# def drop_column(df, col_name):
#   return df.drop(col_name, axis=1)

# def fix_index(df):
#   return df.reset_index(drop=True)

# def fix_dates(df, col_name):
#   df[col_name] = pd.to_datetime(df[col_name])
#   return df

# %%
type(df['employed_date'][2])
# Out:
# str

# %%
fix_dates(df, "employed_date")
# Out:
#     first_name  last_name                           email  gender  \
# 0     Rosamond     Dourin               rdourin0@xing.com  Female
# 1         Mira      Giamo               mgiamo1@ameblo.jp  Female
# 2       August     Nelmes                anelmes2@bbb.org    Male
# 3        Carla  Franzotto                             NaN  Female
# 4        Paxon   Partrick           ppartrick4@drupal.org    Male
# ..         ...        ...                             ...     ...
# 995       Cele    Drennan         cdrennanrn@google.co.uk  Female
# 996     Cristy   Nortunen        cnortunenro@freewebs.com  Female
# 997      Grete    Elcoate  gelcoaterp@merriam-webster.com  Female
# 998    Wilfrid    Canadas                             NaN    Male
# 999   Catriona      Rapps                 crappsrr@nhs.uk  Female
#
#     employed_date            department    salary      bonus
# 0             NaT  Business Development   91048.0  10.000000
# 1             NaT                 Legal  146665.0   2.000000
# 2      2014-09-07            Accounting  161814.0  14.000000
# 3      2015-06-19       Human Resources  168816.0   8.000000
# 4      2018-04-15            Accounting  136121.0   7.699856
# ..            ...                   ...       ...        ...
# 995           NaT    Product Management  144649.0   7.699856
# 996    2016-01-28           Engineering  120389.0   2.000000
# 997    2017-05-25               Support   86544.0   7.699856
# 998    2018-12-19             Marketing   92586.0   7.699856
# 999    2013-03-27             Marketing   93899.0   3.000000
#
# [1000 rows x 8 columns]

# %%
problem_df = drop_empty(df)
fix_index(problem_df)
# Out:
#     first_name last_name                           email   gender  \
# 0       August    Nelmes                anelmes2@bbb.org     Male
# 1        Paxon  Partrick           ppartrick4@drupal.org     Male
# 2      Marabel    Belamy           mbelamy5@amazon.co.uk   Female
# 3    Whittaker     Cluet           wcluet6@angelfire.com     Male
# 4     Timothee    McVane         tmcvane8@opensource.org     Male
# ..         ...       ...                             ...      ...
# 672    Maurine   Greeson           mgreesonrl@census.gov   Female
# 673       Sile    Frarey         sfrareyrm@sitemeter.com  Agender
# 674     Cristy  Nortunen        cnortunenro@freewebs.com   Female
# 675      Grete   Elcoate  gelcoaterp@merriam-webster.com   Female
# 676   Catriona     Rapps                 crappsrr@nhs.uk   Female
#
#     employed_date                department    salary      bonus
# 0        9/7/2014                Accounting  161814.0  14.000000
# 1       4/15/2018                Accounting  136121.0   7.699856
# 2       12/5/2018                 Marketing  162777.0   7.699856
# 3       4/13/2018                  Services  114440.0  11.000000
# 4        9/5/2013                   Support  117430.0   8.000000
# ..            ...                       ...       ...        ...
# 672     8/15/2018  Research and Development   95521.0   7.000000
# 673      4/2/2016  Research and Development  136130.0   7.699856
# 674     1/28/2016               Engineering  120389.0   2.000000
# 675     5/25/2017                   Support   86544.0   7.699856
# 676     3/27/2013                 Marketing   93899.0   3.000000
#
# [677 rows x 8 columns]

# %%
fill_empty(df, "bonus")
# Out:
#     first_name  last_name                           email  gender  \
# 0     Rosamond     Dourin               rdourin0@xing.com  Female
# 1         Mira      Giamo               mgiamo1@ameblo.jp  Female
# 2       August     Nelmes                anelmes2@bbb.org    Male
# 3        Carla  Franzotto                             NaN  Female
# 4        Paxon   Partrick           ppartrick4@drupal.org    Male
# ..         ...        ...                             ...     ...
# 995       Cele    Drennan         cdrennanrn@google.co.uk  Female
# 996     Cristy   Nortunen        cnortunenro@freewebs.com  Female
# 997      Grete    Elcoate  gelcoaterp@merriam-webster.com  Female
# 998    Wilfrid    Canadas                             NaN    Male
# 999   Catriona      Rapps                 crappsrr@nhs.uk  Female
#
#     employed_date            department    salary      bonus
# 0             NaN  Business Development   91048.0  10.000000
# 1             NaN                 Legal  146665.0   2.000000
# 2        9/7/2014            Accounting  161814.0  14.000000
# 3       6/19/2015       Human Resources  168816.0   8.000000
# 4       4/15/2018            Accounting  136121.0   7.699856
# ..            ...                   ...       ...        ...
# 995           NaN    Product Management  144649.0   7.699856
# 996     1/28/2016           Engineering  120389.0   2.000000
# 997     5/25/2017               Support   86544.0   7.699856
# 998    12/19/2018             Marketing   92586.0   7.699856
# 999     3/27/2013             Marketing   93899.0   3.000000
#
# [1000 rows x 8 columns]

# %%
drop_column(df, "email")
# Out:
#     first_name  last_name  gender employed_date            department  \
# 0     Rosamond     Dourin  Female           NaN  Business Development
# 1         Mira      Giamo  Female           NaN                 Legal
# 2       August     Nelmes    Male      9/7/2014            Accounting
# 3        Carla  Franzotto  Female     6/19/2015       Human Resources
# 4        Paxon   Partrick    Male     4/15/2018            Accounting
# ..         ...        ...     ...           ...                   ...
# 995       Cele    Drennan  Female           NaN    Product Management
# 996     Cristy   Nortunen  Female     1/28/2016           Engineering
# 997      Grete    Elcoate  Female     5/25/2017               Support
# 998    Wilfrid    Canadas    Male    12/19/2018             Marketing
# 999   Catriona      Rapps  Female     3/27/2013             Marketing
#
#        salary      bonus
# 0     91048.0  10.000000
# 1    146665.0   2.000000
# 2    161814.0  14.000000
# 3    168816.0   8.000000
# 4    136121.0   7.699856
# ..        ...        ...
# 995  144649.0   7.699856
# 996  120389.0   2.000000
# 997   86544.0   7.699856
# 998   92586.0   7.699856
# 999   93899.0   3.000000
#
# [1000 rows x 7 columns]

# %%
import dataframe_cleaner
import pandas as pd

# %%
df = pd.read_csv("sample_employees.csv")
df
# Out:
#     first_name  last_name                           email  gender  \
# 0     Rosamond     Dourin               rdourin0@xing.com  Female
# 1         Mira      Giamo               mgiamo1@ameblo.jp  Female
# 2       August     Nelmes                anelmes2@bbb.org    Male
# 3        Carla  Franzotto                             NaN  Female
# 4        Paxon   Partrick           ppartrick4@drupal.org    Male
# ..         ...        ...                             ...     ...
# 995       Cele    Drennan         cdrennanrn@google.co.uk  Female
# 996     Cristy   Nortunen        cnortunenro@freewebs.com  Female
# 997      Grete    Elcoate  gelcoaterp@merriam-webster.com  Female
# 998    Wilfrid    Canadas                             NaN    Male
# 999   Catriona      Rapps                 crappsrr@nhs.uk  Female
#
#     employed_date            department    salary  bonus
# 0             NaN  Business Development   91048.0   10.0
# 1             NaN                 Legal  146665.0    2.0
# 2        9/7/2014            Accounting  161814.0   14.0
# 3       6/19/2015       Human Resources  168816.0    8.0
# 4       4/15/2018            Accounting  136121.0    NaN
# ..            ...                   ...       ...    ...
# 995           NaN    Product Management  144649.0    NaN
# 996     1/28/2016           Engineering  120389.0    2.0
# 997     5/25/2017               Support   86544.0    NaN
# 998    12/19/2018             Marketing   92586.0    NaN
# 999     3/27/2013             Marketing   93899.0    3.0
#
# [1000 rows x 8 columns]

# %%
dataframe_cleaner.drop_empty(df)
# Out:
#     first_name    last_name                            email  gender  \
# 2       August       Nelmes                 anelmes2@bbb.org    Male
# 6    Whittaker        Cluet            wcluet6@angelfire.com    Male
# 8     Timothee       McVane          tmcvane8@opensource.org    Male
# 11       Shell  Zecchinelli  szecchinellib@blogtalkradio.com    Male
# 12        Dill      Iglesia                   diglesiac@g.co    Male
# ..         ...          ...                              ...     ...
# 990   Theobald       Hatley            thatleyri@state.tx.us    Male
# 992     Franky       McDell          fmcdellrk@pinterest.com  Female
# 993    Maurine      Greeson            mgreesonrl@census.gov  Female
# 996     Cristy     Nortunen         cnortunenro@freewebs.com  Female
# 999   Catriona        Rapps                  crappsrr@nhs.uk  Female
#
#     employed_date                department    salary  bonus
# 2        9/7/2014                Accounting  161814.0   14.0
# 6       4/13/2018                  Services  114440.0   11.0
# 8        9/5/2013                   Support  117430.0    8.0
# 11      2/27/2016        Product Management  154034.0   13.0
# 12      2/19/2018                   Support   64334.0    4.0
# ..            ...                       ...       ...    ...
# 990      5/9/2016           Human Resources  175423.0   12.0
# 992     4/24/2017      Business Development   85666.0   12.0
# 993     8/15/2018  Research and Development   95521.0    7.0
# 996     1/28/2016               Engineering  120389.0    2.0
# 999     3/27/2013                 Marketing   93899.0    3.0
#
# [464 rows x 8 columns]

# %%
dataframe_cleaner.test(df)
# Out:
# 'hi'

# %%
def kajwenld()
